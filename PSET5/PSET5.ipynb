# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/local/Cellar/python/3.6.4_3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## First double-inline filter:
#
# ![Double filter circuit](images/circuit1.png)

# %% [markdown]
# #### Collected Data

# %%
bode_plot("data/Bode_1.csv")

# %% [markdown]
# ## Second double-inline RC filter:
#
# ![Double filter circuit](images/circuit2.png)

# %% [markdown]
# #### Collected Data

# %%
bode_plot("data/Bode_2.csv")

# %% [markdown]
# #### Collected Data

# %% [markdown]
# ## Third double-inline RC filter (flipped):
#
# ![Double filter circuit](images/circuit3.png)

# %%
bode_plot("data/Bode_3.csv")

# %% [markdown]
# ## Fourth double-inline CR filter:
#
# ![Double filter CR circuit](images/circuit4.png)

# %%
bode_plot("data/Bode_4.csv")

# %% [markdown]
# ## Double inline CR-CR filter:
#
# ![Double filter CR circuit](images/circuit5.png)

# %%
bode_plot("data/Bode_5.csv")

# %%
def bode_plot(file, title = "Bode Plot"):
    data = pd.read_csv(file, skiprows = 20)
    w = data['Frequency (Hz)']
    magnitude = data['Channel 2 Magnitude (dB)']
    phase = data['Channel 2 Phase (°)']
    
    fig = plt.figure(dpi = 150)
    ax1 = plt.subplot(211)
    plt.semilogx(w, magnitude)    # Bode magnitude plot
    plt.title(title)
    plt.ylabel("Magnitude (dB)")
    
    ax2 = plt.subplot(212)
    plt.semilogx(w, phase)  # Bode phase plot
    plt.ylabel("Phase (°)")    
    plt.subplots_adjust(wspace=0, hspace=.05)
    plt.xlabel("Frequency (Hz)")
    plt.show()
