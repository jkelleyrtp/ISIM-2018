# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
#file = "heartbeatadi.csv"
file = "ekgTrace.csv"

pulse = pd.read_csv(file, skiprows = 9)
#pulse['Time (s)'] += 5.005

# %%
y = np.fft.fft(pulse['Channel 1 (V)'])
freq = np.fft.fftfreq(len(pulse['Channel 1 (V)']), pulse['Time (s)'][1] - pulse['Time (s)'][0])

plt.figure(dpi = 200)
plt.xlim((0,65))
plt.ylim((0, 475))
plt.plot(freq, np.abs(y))
#plt.plot(freq, np.angle(y))

# %%
plt.plot(data['Channel 2 (V)'])

# %%
data['Time (s)'][0]
# Out:
# -5.005
